# %%
import pandas as pd

# %%
kaggle_metadata = pd.read_csv("movies_metadata.csv", low_memory = False)
ratings = pd.read_csv("ratings.csv")

# %%
kaggle_metadata.head(10)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# 9  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
kaggle_metadata.sample(n=5)
# Out:
#        adult                              belongs_to_collection budget  \
# 37972  False                                                NaN      0
# 22745  False                                                NaN      0
# 9653   False                                                NaN      0
# 27634  False                                                NaN      0
# 13929  False  {'id': 115142, 'name': 'Tales from the Crypt C...      0
#
#                                                   genres homepage      id  \
# 37972  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   61908
# 22745                   [{'id': 53, 'name': 'Thriller'}]      NaN   87293
# 9653   [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...      NaN   22559
# 27634  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  119353
# 13929                     [{'id': 27, 'name': 'Horror'}]      NaN   53868
#
#          imdb_id original_language        original_title  \
# ...

# %%
wiki_movies_df = pd.DataFrame(kaggle_metadata)
wiki_movies_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# Initial look at kaggle metadata
kaggle_metadata.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %%
kaggle_metadata['adult'].value_counts()
# Out:
# False                                                                                                                             45454
# True                                                                                                                                  9
#  - Written by Ørnås                                                                                                                   1
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
# Name: adult, dtype: int64

# %%
# Removing bad data
kaggle_metadata[~kaggle_metadata['adult'].isin(['True', 'False'])]
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# ...

# %%
kaggle_metadata = kaggle_metadata[kaggle_metadata['adult'] == 'False']#.drop('adult', axis='columns')

# %%
# Values of video column 
kaggle_metadata['video'].value_counts()
# Out:
# False    45358
# True        93
# Name: video, dtype: int64

# %%
# convert Data Types
kaggle_metadata['video'] == 'True'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: video, Length: 45454, dtype: bool

# %%
# Assign back to video
kaggle_metadata['video'] = kaggle_metadata['video'] == 'True'

# %%
kaggle_metadata['budget'] = kaggle_metadata['budget'].astype(int)
kaggle_metadata['id'] = pd.to_numeric(kaggle_metadata['id'], errors='raise')
kaggle_metadata['popularity'] = pd.to_numeric(kaggle_metadata['popularity'], errors='raise')

# %%
kaggle_metadata['release_date'] = pd.to_datetime(kaggle_metadata['release_date'])

# %%
# Reasonablility Checks on Ratings Data
ratings.info(null_counts = True)
# Out:
# /Users/christianbarbosa/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: null_counts is deprecated. Use show_counts instead
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Non-Null Count     Dtype
# ---  ------     --------------     -----
#  0   userId     26024289 non-null  int64
#  1   movieId    26024289 non-null  int64
#  2   rating     26024289 non-null  float64
#  3   timestamp  26024289 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB

# %%
pd.to_datetime(ratings['timestamp'], unit = 's')
# Out:
# 0          2015-03-09 22:52:09
# 1          2015-03-09 23:07:15
# 2          2015-03-09 22:52:03
# 3          2015-03-09 22:52:26
# 4          2015-03-09 22:52:36
#                    ...
# 26024284   2009-10-31 23:26:04
# 26024285   2009-10-31 23:33:52
# 26024286   2009-10-31 23:29:24
# 26024287   2009-11-01 00:06:30
# 26024288   2009-10-31 23:30:58
# Name: timestamp, Length: 26024289, dtype: datetime64[ns]

# %%
ratings['timestamp'] = pd.to_datetime(ratings['timestamp'], unit = 's')

# %%
# Display histogram
pd.options.display.float_format = '{:20,.2f}'.format
ratings['rating'].plot(kind = 'hist')
ratings['rating'].describe()
# Out:
# count          26,024,289.00
# mean                    3.53
# std                     1.07
# min                     0.50
# 25%                     3.00
# 50%                     3.50
# 75%                     4.00
# max                     5.00
# Name: rating, dtype: float64

# %%
# Print out a list of columns to identify redundancy 
movies_df = pd.merge(wiki_movies_df, kaggle_metadata, on='imdb_id', suffixes=['_wiki','_kaggle'])
movies_df.head()
# Out:
#   adult_wiki                         belongs_to_collection_wiki budget_wiki  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...    30000000
# 1      False                                                NaN    65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...           0
# 3      False                                                NaN    16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...           0
#
#                                          genres_wiki  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                           homepage_wiki id_wiki    imdb_id  \
# 0  http://toystory.disney.com/toy-story     862  tt0114709
# 1                                   NaN    8844  tt0113497
# ...

# %%
# Competing data:
# Wiki                     Movielens                Resolution
#--------------------------------------------------------------------------
# title_wiki               title_kaggle
# running_time             runtime
# budget_wiki              budget_kaggle
# box_office               revenue
# release_date_wiki        release_date_kaggle
# Language                 original_language
# Production company(s)    production_companies

# %%
# Comparing Title Columns
movies_df[['title_wiki','title_kaggle']]
# Out:
#                         title_wiki                 title_kaggle
# 0                        Toy Story                    Toy Story
# 1                          Jumanji                      Jumanji
# 2                 Grumpier Old Men             Grumpier Old Men
# 3                Waiting to Exhale            Waiting to Exhale
# 4      Father of the Bride Part II  Father of the Bride Part II
# ...                            ...                          ...
# 45783                       Subdue                       Subdue
# 45784          Century of Birthing          Century of Birthing
# 45785                     Betrayal                     Betrayal
# 45786             Satan Triumphant             Satan Triumphant
# 45787                     Queerama                     Queerama
#
# [45788 rows x 2 columns]

# %%
# Titles that dont match
movies_df[movies_df['title_wiki'] != movies_df['title_kaggle']][['title_wiki','title_kaggle']]
# Out:
#                            title_wiki  \
# 9002                         Delusion
# 9003                         Delusion
# 9004                         Delusion
# 9005                         Delusion
# 9006                         Delusion
# ...                               ...
# 9287   The Garden of Afflictions 2017
# 9288   The Garden of Afflictions 2017
# 20082                             NaN
# 29845                             NaN
# 35925                             NaN
#
#                                             title_kaggle
# 9002                                                Show
# 9003   How I Unleashed World War II Part III: Among F...
# 9004                                         Dreamkiller
# 9005                                          The Winner
# 9006        Before The Dinosaurs - Walking With Monsters
# ...                                                  ...
# 9287                      H2O Just Add Water - The Movie
# ...

# %%
# Show any rows where tille_kaggle is empty
movies_df[(movies_df['title_kaggle'] == '')|(movies_df['title_kaggle'].isnull())]
# Out:
#       adult_wiki                         belongs_to_collection_wiki  \
# 20082      False                                                NaN
# 29845      False  {'id': 122661, 'name': 'Mardock Scramble Colle...
# 35925      False                                                NaN
#
#       budget_wiki                                        genres_wiki  \
# 20082           0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 29845           0  [{'id': 16, 'name': 'Animation'}, {'id': 878, ...
# 35925           0  [{'id': 10770, 'name': 'TV Movie'}, {'id': 28,...
#
#                        homepage_wiki id_wiki    imdb_id  \
# 20082                            NaN   82663  tt0113002
# 29845  http://m-scramble.jp/exhaust/  122662  tt2423504
# 35925                            NaN  249260  tt2622826
#
#       original_language_wiki original_title_wiki  \
# 20082                     en        Midnight Man
# 29845                     ja    マルドゥック・スクランブル 排気
# ...

# %%
# Run time
#movies_df.fillna(0).plot(x='running_time', y= 'runtime', kind = 'scatter')
